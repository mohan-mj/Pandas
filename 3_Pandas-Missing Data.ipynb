# %%
import pandas as pd
import numpy as np

# %%
d = {'A':[1,2,np.nan], 'B':[5, np.nan, np.nan], 'C':[1,2,3]}
df = pd.DataFrame(d)

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna(axis=1)
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
df.dropna(thresh=2)
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2

# %%
df.dropna(thresh=2, axis= 1)
# Out:
#      A  C
# 0  1.0  1
# 1  2.0  2
# 2  NaN  3

# %%
df.fillna(value='Fill Value')
# Out:
#             A           B  C
# 0           1           5  1
# 1           2  Fill Value  2
# 2  Fill Value  Fill Value  3

# %%
df['A'].fillna(value=df['A'].mean())
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %% [markdown]
# ### Gropupby

# %%
data = { 'company':['Google','FB','Apple','Microsoft','Google','FB','Apple'],
       'Person':['A','B','C','D','E','E','F'],
       'sales':list(abs(np.random.randn(7)) * 100)}

# %%
df = pd.DataFrame(data)
df
# Out:
#   Person    company       sales
# 0      A     Google   74.279555
# 1      B         FB  113.229755
# 2      C      Apple   70.431599
# 3      D  Microsoft    0.404650
# 4      E     Google  124.774777
# 5      E         FB   67.123737
# 6      F      Apple  246.646582

# %%
df.groupby('company').mean()
# Out:
#                 sales
# company
# Apple      158.539091
# FB          90.176746
# Google      99.527166
# Microsoft    0.404650

# %%
df.groupby('company').mean().loc['Apple']
# Out:
# sales    158.539091
# Name: Apple, dtype: float64

# %%
df.groupby('company').std()
# Out:
#                 sales
# company
# Apple      124.602810
# FB          32.601878
# Google      35.705514
# Microsoft         NaN

# %%
df.groupby('company').describe()
# Out:
#           sales                                                             \
#           count        mean         std        min         25%         50%
# company
# Apple       2.0  158.539091  124.602810  70.431599  114.485345  158.539091
# FB          2.0   90.176746   32.601878  67.123737   78.650242   90.176746
# Google      2.0   99.527166   35.705514  74.279555   86.903361   99.527166
# Microsoft   1.0    0.404650         NaN   0.404650    0.404650    0.404650
#
#
#                   75%         max
# company
# Apple      202.592837  246.646582
# FB         101.703251  113.229755
# Google     112.150972  124.774777
# Microsoft    0.404650    0.404650

# %%
set(df['company'].values)
# Out:
# {'Apple', 'FB', 'Google', 'Microsoft'}
